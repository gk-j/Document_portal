# %%
print("wr")
# Out:
# wr

# %% [markdown]
# ### __file__ in .py file automatically gets the name of the file

# %%
from logger.custom_logger import customLogger

# %%
custom_logger=customLogger()
logger=custom_logger.get_logger("exception_experiment")

# %%
import sys
import traceback

# %%
class DocumentPortalException(Exception):
    """Custom exception for Document portal"""
    def __init__(self,error_message:str,error_details:sys ):
        _,_,exc_tb=error_details.exc_info()
        self.file_name=exc_tb.tb_frame.f_code.co_filename
        self.lineno=exc_tb.tb_lineno
        self.error_message=str(error_message)
        self.traceback_str=''.join(traceback.format_exception(*error_details.exc_info()))

    def __str__(self):
        return f"""
    Error in [{self.file_name}] at line [{self.lineno}]
    Message: {self.error_message}   
    Traceback:{self.traceback_str}
        """

if __name__== "__main__": 
    try:
        #simulate an error
        a=1/0
        print(a)
    except Exception as e:
        app_exec=DocumentPortalException(e,sys)
        raise app_exec
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[4], line 20
#      18 try:
#      19     #simulate an error
# ---> 20     a=1/0
#      21     print(a)
#
# ZeroDivisionError: division by zero
#
# During handling of the above exception, another exception occurred:
#
# DocumentPortalException                   Traceback (most recent call last)
# Cell In[4], line 24
#      22 except Exception as e:
#      23     app_exec=DocumentPortalException(e,sys)
# ---> 24     raise app_exec
#
# DocumentPortalException:
#     Error in [/var/folders/t9/j8p1r2vd56vf7xq1d1mm0hz40000gn/T/ipykernel_21689/377232600.py] at line [20]
#     Message: division by zero
#     Traceback:Traceback (most recent call last):
#   File "/var/folders/t9/j8p1r2vd56vf7xq1d1mm0hz40000gn/T/ipykernel_21689/377232600.py", line 20, in <module>
#     a=1/0
# ZeroDivisionError: division by zero

# %%
class DocumentPortalException(Exception):
    """Custom exception for Document portal"""
    def __init__(self,error_message:str,error_details:sys ):
        _,_,exc_tb=error_details.exc_info()
        self.file_name=exc_tb.tb_frame.f_code.co_filename
        self.lineno=exc_tb.tb_lineno
        self.error_message=str(error_message)
        self.traceback_str=''.join(traceback.format_exception(*error_details.exc_info()))

    def __str__(self):
        return f"""
    Error in [{self.file_name}] at line [{self.lineno}]
    Message: {self.error_message}   
    Traceback:{self.traceback_str}
        """

if __name__== "__main__": 
    try:
        #simulate an error
        a=1/0
        print(a)
    except Exception as e:
        app_exec=DocumentPortalException(e,sys)
        logger.error(app_exec)
        raise app_exec
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[14], line 20
#      18 try:
#      19     #simulate an error
# ---> 20     a=1/0
#      21     print(a)
#
# ZeroDivisionError: division by zero
#
# During handling of the above exception, another exception occurred:
#
# DocumentPortalException                   Traceback (most recent call last)
# Cell In[14], line 25
#      23 app_exec=DocumentPortalException(e,sys)
#      24 logger.error(app_exec)
# ---> 25 raise app_exec
#
# DocumentPortalException:
#     Error in [/var/folders/t9/j8p1r2vd56vf7xq1d1mm0hz40000gn/T/ipykernel_21689/2977684307.py] at line [20]
#     Message: division by zero
#     Traceback:Traceback (most recent call last):
#   File "/var/folders/t9/j8p1r2vd56vf7xq1d1mm0hz40000gn/T/ipykernel_21689/2977684307.py", line 20, in <module>
#     a=1/0
# ZeroDivisionError: division by zero
