# %%
print("all")
# Out:
# all

# %%
import logging 
import os
from datetime import datetime

# %%
print(os.path.join(os.getcwd()))
# Out:
# /Users/gkj/Documents/llmops/document_portal/notebooks

# %%
log_dir=os.path.join(os.getcwd(),"logs")
os.makedirs(log_dir,exist_ok=True)
## creating logs folder in current directory

# %%
#naming the log files as current time
LOG_FILE=f"{datetime.now().strftime('%m_%d_%Y_%H_%M_%S')}.log"

# %%
LOG_FILE
# Out:
# '08_03_2025_16_05_31.log'

# %%
LOG_FILE_PATH=os.path.join(log_dir,LOG_FILE)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
logging.basicConfig(
    filename=LOG_FILE_PATH,
    format="[%(asctime)s ] %(levelname)s %(name)s (line:%(lineno)d) - %(message)s",
    level=logging.INFO
)

# %%
logger= logging.getLogger("DocumentPortal")

# %%
logger.info("This is a info message")

# %%
logger.error("Error!!!!!")

# %% [markdown]
# #### logging using structlog

# %%
import structlog
# we can structure the log in json or yaml or... 
logger = structlog.get_logger("DocumentPortal")

# %%
logger.info("User uploaded a file",user_id=123,filename='file.pdf')
# Out:
# 2025-07-27 17:46:25 [info     ] User uploaded a file           filename=file.pdf user_id=123

# %%
logger.error("Failed to process PDF", error="File not found", user_id=123)
# Out:
# 2025-07-27 17:47:32 [error    ] Failed to process PDF          error='File not found' user_id=123

# %% [markdown]
# AWS Repo(ELK)
# ECS LOGS
# Cloud Watch
